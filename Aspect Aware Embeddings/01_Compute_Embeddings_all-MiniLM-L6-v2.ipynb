# %%
# !pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting transformers<5.0.0,>=4.6.0 (from sentence-transformers)
#   Downloading transformers-4.33.2-py3-none-any.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 65.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.15.2+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.23.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (3.8.1)
# Collecting sentencepiece (from sentence-transformers)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 44.0 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0 (from sentence-transformers)
#   Downloading huggingface_hub-0.17.2-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 37.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers) (16.0.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2023.6.3)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers<5.0.0,>=4.6.0->sentence-transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 119.4 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers<5.0.0,>=4.6.0->sentence-transformers)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 83.2 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=c7c84c62cb0e14f3c2dab77cf0986b2fa63d49a5866261d0a0a5f96fa32e34fd
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# Installing collected packages: tokenizers, sentencepiece, safetensors, huggingface-hub, transformers, sentence-transformers
# Successfully installed huggingface-hub-0.17.2 safetensors-0.3.3 sentence-transformers-2.2.2 sentencepiece-0.1.99 tokenizers-0.13.3 transformers-4.33.2

# %%
import pandas as pd
from google.colab import drive
import os
from sentence_transformers import SentenceTransformer
import pickle

# %%
drive.mount('/content/gdrive')
csv_path = '/content/gdrive/My Drive/Colab Data'
# Out:
# Mounted at /content/gdrive

# %%
race_df_train = pd.read_csv(os.path.join(csv_path, 'race_train.csv'))
race_df_train
# Out:
#            example_id                                            article  \
# 0      middle2748.txt  Not long ago, the only time you could see a ro...
# 1      middle1649.txt  Shopping used to mean actually going to shops,...
# 2       middle654.txt  As a girl, I've spent a great deal of my time ...
# 3      middle2741.txt  Do you like playing football? If you do, you m...
# 4        middle65.txt  "Can I see my baby?" the happy new mother aske...
# ...               ...                                                ...
# 38101        1302.txt  Vernon Bowman, a 75-year-old farmer from rural...
# 38102        2170.txt  The rough guide to marketing success used to b...
# 38103        1877.txt  Open data sharers are still in the minority in...
# 38104        3148.txt  Fear and its companion pain are two of the mos...
# 38105         985.txt  Most people think of racing when they see grey...
#
#        answer                                           question  \
# 0           3  Robots may deal with information that humans c...
# 1           3  Nowadays many people like shopping online inst...
# 2           1           We can learn from the passage that  _  .
# 3           0  If you don't do well in your study, who won't ...
# 4           2                 From the passage, we know "  _  ".
# ...       ...                                                ...
# 38101       2  What are Monsanto?s critics hoping the Supreme...
# 38102       0  Toyota Motor's experience is cited as an examp...
# 38103       3         What do many researchers generally accept?
# 38104       1  People sometimes succeed in timely avoiding da...
# 38105       3            It can be inferred that greyhounds  _ .
#
#                                                  options difficulty  \
# 0      ['They do not have so many limits as humans do...          M
# 1      ['clicking their mouse' 'paying money'\n 'sitt...          M
# 2      ['the girl has learnt salsa for a long time'\n...          M
# 3      ['your teachers and parents' 'your classmates ...          M
# 4      ['ears are very important' 'no ears are good' ...          M
# ...                                                  ...        ...
# 38101  ['Allow small farmers to grow genetically modi...          C
# 38102  ['responding effectively to hijacked media'\n ...          C
# 38103  ["It is imperative to protect scientists' pate...          C
# 38104  ['they have gained experience'\n 'they are war...          C
# 38105  ['love big doghouses' 'like staying in bed all...          C
#
#                                                     text
# 0      ### CONTEXT ###\nNot long ago, the only time y...
# 1      ### CONTEXT ###\nShopping used to mean actuall...
# 2      ### CONTEXT ###\nAs a girl, I've spent a great...
# 3      ### CONTEXT ###\nDo you like playing football?...
# 4      ### CONTEXT ###\n"Can I see my baby?" the happ...
# ...                                                  ...
# 38101  ### CONTEXT ###\nVernon Bowman, a 75-year-old ...
# 38102  ### CONTEXT ###\nThe rough guide to marketing ...
# 38103  ### CONTEXT ###\nOpen data sharers are still i...
# 38104  ### CONTEXT ###\nFear and its companion pain a...
# 38105  ### CONTEXT ###\nMost people think of racing w...
#
# [38106 rows x 7 columns]

# %%
race_df_validation = pd.read_csv(os.path.join(csv_path, 'race_validation.csv'))
race_df_validation
# Out:
#           example_id                                            article  \
# 0      middle490.txt  In England people can go to see a doctor nearb...
# 1     middle1650.txt  Motor cars were first made in England just bef...
# 2      middle946.txt  It's Saturday evening. Bruce is having a birth...
# 3     middle2289.txt  People began to make robots about several hund...
# 4     middle6704.txt  Look at the instructions on the bottle of the ...
# ...              ...                                                ...
# 2131         808.txt  Hardly a week goes by without some advance in ...
# 2132         962.txt  The man who invented Coca-cola was not a nativ...
# 2133        1642.txt  Trees should only be pruned when there is a go...
# 2134        1787.txt  It is a curious paradox that we think of the p...
# 2135         614.txt  " This is not the type of place where this hap...
#
#       answer                                           question  \
# 0          0     When people are ill in England, they'll   _  .
# 1          3   The first motor cars were probably made by  _  .
# 2          2  What are the children doing in the afternoon? ...
# 3          2               What's the possible meaning of dumb?
# 4          0  John will  _   the medicine when it is left af...
# ...      ...                                                ...
# 2131       1    From the second paragraph, we can infer that  _
# 2132       0  What does the passage tell us about John Styth...
# 2133       0         Trees become unhealthy if the gardener _ .
# 2134       0  The chances of the physical sciences being sub...
# 2135       1  Alvin Holmes‘ attitude toward the gay victims ...
#
#                                                 options difficulty  \
# 0     ['go to see the doctor nearby' 'go to the medi...          M
# 1     ['Europeans' 'the Whites' 'the Blacks' 'the En...          M
# 2             ['reading' 'singing' 'playing' 'dancing']          M
# 3     ['Talking like people.' 'Clever.' 'Unintellige...          M
# 4     ['throw away' 'stop to take' 'take once' 'take...          M
# ...                                                 ...        ...
# 2131  ["professionals won't be affected by new techn...          C
# 2132  ['He was highly respected by Atlantans.'\n 'He...          C
# 2133  ['allows too many branches to grow in the midd...          C
# 2134  ['contradictory theories keep emerging all the...          C
# 2135  ['indifferent' 'sympathetic' 'outrageous' 'con...          C
#
#                                                    text
# 0     ### CONTEXT ###\nIn England people can go to s...
# 1     ### CONTEXT ###\nMotor cars were first made in...
# 2     ### CONTEXT ###\nIt's Saturday evening. Bruce ...
# 3     ### CONTEXT ###\nPeople began to make robots a...
# 4     ### CONTEXT ###\nLook at the instructions on t...
# ...                                                 ...
# 2131  ### CONTEXT ###\nHardly a week goes by without...
# 2132  ### CONTEXT ###\nThe man who invented Coca-col...
# 2133  ### CONTEXT ###\nTrees should only be pruned w...
# 2134  ### CONTEXT ###\nIt is a curious paradox that ...
# 2135  ### CONTEXT ###\n" This is not the type of pla...
#
# [2136 rows x 7 columns]

# %%
race_df_test = pd.read_csv(os.path.join(csv_path, 'race_test.csv'))
race_df_test
# Out:
#           example_id                                            article  \
# 0     middle3297.txt  Joe Read studied in this school for fourteen y...
# 1     middle7083.txt  The Chinese tradition of giving gifts of money...
# 2     middle7598.txt  Chinese writer Mo Yan won the Nobel Prize in L...
# 3     middle1556.txt  Are you an only-child in your family? Are you ...
# 4     middle1183.txt  People usually hate mice, but people almost al...
# ...              ...                                                ...
# 2119        1990.txt  If the trade unionist Jimmy Hoffa were alive t...
# 2120        1219.txt  The unhappy history of Ukraine, Russia and gas...
# 2121         500.txt  The power and ambition of the giants of the di...
# 2122        3365.txt  One of our biggest fears nowadays is that our ...
# 2123         415.txt  It's hardly news that the immigration system i...
#
#       answer                                           question  \
# 0          0                  What did his father think of Joe?
# 1          1        Which one is TRUE according to the passage?
# 2          3                       Where was Barack Obama born?
# 3          1                What can we learn from the passage?
# 4          1                   Why did Disney make Donald Duck?
# ...      ...                                                ...
# 2119       3     Which of the following is true of Paragraph 2?
# 2120       0  According to the author, what matters most is ...
# 2121       3  The White House claims that its power of enfor...
# 2122       2  According to the passage, children without exp...
# 2123       2  We learn from the passage that coordinated eff...
#
#                                                 options difficulty  \
# 0     ['He was a good student.' "He wasn't a good st...          M
# 1     ['Tencent allows Alipay to send red envelopes ...          M
# 2     ['In Kansas.' 'In Kenya.' 'In Golumbia.' 'In H...          M
# 3     ["Zhang Luwen's parents bath every week."\n 'Z...          M
# 4     ['Because Mickey Mouse was very lonely'\n 'Bec...          M
# ...                                                 ...        ...
# 2119  ['Public-sector unions are prudent in taking a...          C
# 2120  ['many countries depend on Russia for their en...          C
# 2121  ['they are not defined as customers' 'they are...          C
# 2122  ['keep a high sense of wonder' 'be over-protec...          C
# 2123  ['limit the number Of immigrants to the U.S.'\...          C
#
#                                                    text
# 0     ### CONTEXT ###\nJoe Read studied in this scho...
# 1     ### CONTEXT ###\nThe Chinese tradition of givi...
# 2     ### CONTEXT ###\nChinese writer Mo Yan won the...
# 3     ### CONTEXT ###\nAre you an only-child in your...
# 4     ### CONTEXT ###\nPeople usually hate mice, but...
# ...                                                 ...
# 2119  ### CONTEXT ###\nIf the trade unionist Jimmy H...
# 2120  ### CONTEXT ###\nThe unhappy history of Ukrain...
# 2121  ### CONTEXT ###\nThe power and ambition of the...
# 2122  ### CONTEXT ###\nOne of our biggest fears nowa...
# 2123  ### CONTEXT ###\nIt's hardly news that the imm...
#
# [2124 rows x 7 columns]

# %%
dolly_cqa_df = pd.read_csv(os.path.join(csv_path, 'dolly_cqa.csv'))
dolly_cqa_df
# Out:
#                                             instruction  \
# 0            When did Virgin Australia start operating?
# 1                       When was Tomoaki Komorida born?
# 2     Given a reference text about Lollapalooza, whe...
# 3     Who was Kyle Van Zyl playing against when he s...
# 4     Who was the first to record the Needles and Pi...
# ...                                                 ...
# 1768  How many types of cat does the world cat feder...
# 1769                     What is the history of coffee?
# 1770  What are common florals found in Zigalga Natio...
# 1771                           What is linux Bootloader
# 1772                          What is one-child policy?
#
#                                                 context  \
# 0     Virgin Australia, the trading name of Virgin A...
# 1     Komorida was born in Kumamoto Prefecture on Ju...
# 2     Lollapalooza /ˌlɒləpəˈluːzə/ (Lolla) is an ann...
# 3     Van Zyl joined the Eastern Province Kings Acad...
# 4     "Needles and Pins" is a rock song credited to ...
# ...                                                 ...
# 1768  As of 2023, The International Cat Association ...
# 1769  The history of coffee dates back to centuries ...
# 1770  Zigalga National Park (Russian: Национальный п...
# 1771  A bootloader, also spelled as boot loader or c...
# 1772  The term one-child policy refers to a populati...
#
#                                                response   category  \
# 0     Virgin Australia commenced services on 31 Augu...  closed_qa
# 1            Tomoaki Komorida was born on July 10,1981.  closed_qa
# 2     Lollapalooze is an annual musical festival hel...  closed_qa
# 3     Kyle Van Zyl was playing against Boland U21 wh...  closed_qa
# 4     The first artist to record Needles and Pins so...  closed_qa
# ...                                                 ...        ...
# 1768                                                 69  closed_qa
# 1769  Much of the early history of coffee was tied t...  closed_qa
# 1770  Zigalga National Park has the majority of its ...  closed_qa
# 1771  A bootloader is a program written in machine c...  closed_qa
# 1772  The "one-child policy" was a Chinese populatio...  closed_qa
#
#                                                    text
# 0     ### CONTEXT ###\nVirgin Australia, the trading...
# 1     ### CONTEXT ###\nKomorida was born in Kumamoto...
# 2     ### CONTEXT ###\nLollapalooza /ˌlɒləpəˈluːzə/ ...
# 3     ### CONTEXT ###\nVan Zyl joined the Eastern Pr...
# 4     ### CONTEXT ###\n"Needles and Pins" is a rock ...
# ...                                                 ...
# 1768  ### CONTEXT ###\nAs of 2023, The International...
# 1769  ### CONTEXT ###\nThe history of coffee dates b...
# 1770  ### CONTEXT ###\nZigalga National Park (Russia...
# 1771  ### CONTEXT ###\nA bootloader, also spelled as...
# 1772  ### CONTEXT ###\nThe term one-child policy ref...
#
# [1773 rows x 5 columns]

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
embeddings_train = model.encode(race_df_train['text'].to_list(), batch_size=128, show_progress_bar=True, normalize_embeddings=False)
print(embeddings_train.shape)

with open(os.path.join(csv_path, 'embeddings_train_mini_lm.pickle'), 'wb') as f:
  pickle.dump(embeddings_train, f)
# Out:
# Batches:   0%|          | 0/298 [00:00<?, ?it/s]
# (38106, 384)

# %%
embeddings_validation = model.encode(race_df_validation['text'].to_list(), batch_size=128, show_progress_bar=True, normalize_embeddings=False)
print(embeddings_validation.shape)

with open(os.path.join(csv_path, 'embeddings_validation_mini_lm.pickle'), 'wb') as f:
  pickle.dump(embeddings_validation, f)
# Out:
# Batches:   0%|          | 0/17 [00:00<?, ?it/s]
# (2136, 384)

# %%
embeddings_test = model.encode(race_df_test['text'].to_list(), batch_size=128, show_progress_bar=True, normalize_embeddings=False)
print(embeddings_test.shape)

with open(os.path.join(csv_path, 'embeddings_test_mini_lm.pickle'), 'wb') as f:
  pickle.dump(embeddings_test, f)
# Out:
# Batches:   0%|          | 0/17 [00:00<?, ?it/s]
# (2124, 384)

# %%
embeddings_dolly = model.encode(dolly_cqa_df['text'].to_list(), batch_size=128, show_progress_bar=True, normalize_embeddings=False)
print(embeddings_dolly.shape)

with open(os.path.join(csv_path, 'embeddings_dolly_mini_lm.pickle'), 'wb') as f:
  pickle.dump(embeddings_dolly, f)
# Out:
# Batches:   0%|          | 0/14 [00:00<?, ?it/s]
# (1773, 384)
